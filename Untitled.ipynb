# %%
from parser import parse_resume

resume = parse_resume("resume.txt")

from pprint import pprint

print(resume)
# Out:
# {'filename': 'resume.txt', 'contact': {'email': 'john.smith@gmail.com', 'phone': '+91 9876543210', 'linkedin': 'https://www.linkedin.com/in/johnsmith', 'github': 'https://github.com/johnsmith', 'websites': ['https://www.linkedin.com/in/johnsmith', 'https://github.com/johnsmith', 'https://johnsmith.dev']}, 'entities': {'name': ['JOHN SMITH\nSoftware Engineer', '• Worked', 'Machine Learning', 'Python', 'Cloud Technologies', 'Docker', 'Pandas', 'Cloud Computing', 'Cloud Practitioner', 'Resume Parser', 'Gradio'], 'organization': ['CERTIFICATIONS', 'NLP', 'B.Tech', 'Artificial Intelligence', 'Machine Learning', 'Computer Science\nIndian Institute of Technology Delhi', 'Google Data Analytics Professional Certificate', 'Data Science and Full Stack Development', 'SQL', 'Random Forest', 'Bachelor of Technology'], 'location': ['Flask'], 'date': ['2023', 'January 2024 - June 2024', '2020 - 2024']}, 'skills': ['AWS', 'Azure', 'C++', 'Deep Learning', 'Docker', 'Excel', 'Git', 'Java', 'JavaScript'
# ...

# %%
from parser import parse_resume
from database import insert_resume

resume = parse_resume("resume.txt")

insert_resume(resume)

print("Resume inserted successfully!")
# Out:
# Resume inserted successfully!
